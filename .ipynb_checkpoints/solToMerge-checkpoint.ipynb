# %%
% pylab inline
import pandas as pd
#import numpy as np
import matplotlib as plt
import nltk
from nltk.corpus import stopwords 
import string
import heapq
import operator
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
from nltk.stem.wordnet import WordNetLemmatizer
from collections import Counter
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string
import matplotlib.pyplot as plt
from time import time
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.utils.extmath import density
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier

from keras.models import Sequential
from keras.layers.core import Dense, Activation, Flatten
from keras.layers.wrappers import TimeDistributed
from keras.layers.embeddings import Embedding
from keras.layers.recurrent import LSTM
from keras.layers.embeddings import Embedding
from keras.layers.recurrent import SimpleRNN
from keras.layers import Dense, Dropout, Activation


nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# [nltk_data] Downloading package punkt to /home/oleg/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/oleg/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/oleg/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# /usr/local/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['time']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# True

# %%
def clean(words_string):    
    stop = set(stopwords.words('english'))
    exclude = set(string.punctuation) 
    lemma = WordNetLemmatizer()
    stop_free=" ".join([i for i in words_string.lower().split() if i not in stop])
    punc_free=''.join(ch if ch not in exclude else ' ' for ch in stop_free)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

def uniteLists(list_of_lists_of_words):
    united=[]
    for list_of_words in list_of_lists_of_words:
        united+=list_of_words
    return united
def devideToTermsAndFreq(tfList):
    ans_terms=[]
    ans_freq=[]
    for key,val in tfList:
        ans_terms.append(key)
        ans_freq.append(val)
    return ans_terms,ans_freq
def createPlot(x_data,y_data,y_name,x_name,title,i,j,k,color,bartype):
    axis_font = {'family': 'serif','color':  'black','weight': 'normal','size': 18,}
    title_font = {'family': 'serif','color':  'black','weight': 'normal','size': 22,}
    font_size=16
    df=pd.DataFrame(data={x_name:x_data,y_name:y_data})
    temp = df.pivot_table(values=y_name,index=x_data)
    temp.sort_values(by=(y_name), ascending=True,inplace=True)
    ax = fig.add_subplot(i,j,k) #121
    for tick in ax.xaxis.get_major_ticks():
        tick.label1.set_fontsize(font_size)
    for tick in ax.yaxis.get_major_ticks():
        tick.label1.set_fontsize(font_size)
    ax.set_xlabel(x_name,fontdict=axis_font)
    ax.set_ylabel(y_name,fontdict=axis_font)
    ax.set_title(title,fontdict=title_font)
    temp.plot(kind=bartype,ax=ax,cmap=color)
    
def findColDiff(df,col_name1,col_name2):
    return df[[col_name1,col_name2]][data_df[col_name1] != data_df[col_name2]]

def printNewCols(start,end):
    for i in range(start,end) :
        print(data_df.iloc[i]['text'])
        print(data_df.iloc[i]['clean_text'])
        print(data_df.iloc[i]['clean_words_list'])
        print(data_df.iloc[i]['hashtags'])
        print(data_df.iloc[i]['user_tag'])
        print()

# %%
import pandas as pd
data_df=pd.read_csv('gender-classifier-DFE-791531.csv',header=0,encoding = 'latin1') #iso-8859-1

# %%
print(data_df.axes)

# %% [markdown]
# ### regular expressions for text filtering

# %%
emoticons_str = r"""(?:[:=;][oO\-]?[D\)\]\(\]/\\OpP])"""
html_str=r'<[^>]+>'
user_tags_str=r'(?:@[\w_]+)'
hashtags_str='#[a-zA-Z0-9]+'
url_str= r'http[s]?://(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+'
number_str= r'(?:(?:\d+,?)+(?:\.?\d+)?)'
another_str=r"(?:[a-zA-Z0-9#@][a-zA-Z0-9#@'\-_]+[a-zA-Z0-9#@])" # words with - and '
letters_and_tags_str='[a-z\'A-Z0-9#@][a-z\'A-Z0-9#@.-_]*'

# %% [markdown]
# ### cleaning the data
# - **'text'**- sentence per user cleaned from http links and garbage letters.
# - **'hashtag'**- list of #hashtags per user.
# - **'user_tag'** - list of @user_tags per user.
# - **'clean_text'**- same as 'text' just without #tags and @tags.
# - **'clean_words_list'**- same as 'clean_text' just splitted to list of words per user.

# %%
data_df = data_df[data_df['gender'].apply(lambda x : (x=='male' or x=='female') )]
data_df['emo']= data_df['text'].apply(lambda x : re.findall(emoticons_str,x))

data_df['text']=data_df['text'].apply(lambda x :  re.sub(url_str,"",x))
data_df['text']=data_df['text'].apply(lambda x :  " ".join(re.findall(r'('+'|'.join([letters_and_tags_str,emoticons_str])+')',x)))
data_df['text']=data_df['text'].apply(lambda x :  re.sub('\'','',x))
data_df['text']=data_df['text'].apply(lambda x :  re.sub('-','',x))
data_df['text']=data_df['text'].apply(lambda x :  re.sub('_','',x))
data_df['text']=data_df['text'].apply(lambda x :  re.sub('[\s]+',' ',x))

data_df['hashtags']=data_df['text'].apply(lambda x :  re.findall(hashtags_str,x))
data_df['user_tag']=data_df['text'].apply(lambda x :  re.findall(user_tags_str,x))
data_df['clean_text']=data_df['text'].apply(lambda x :  re.sub('[#@]\S+\s*',"",x))
data_df['clean_text']=data_df['clean_text'].apply(clean)
data_df['clean_words_list']=data_df['clean_text'].apply(lambda x:re.findall('[a-zA-Z0-9]+',x))

# %%
# Out:
# YALL LMFAOO RIGHT WHEN THE CHORUS CAME ON A TEAR ROLLED DOWN HIS FACE
# YALL LMFAOO RIGHT WHEN THE CHORUS CAME ON A TEAR ROLLED DOWN HIS FACE
# YALL LMFAOO RIGHT WHEN THE CHORUS CAME ON, A TEAR ROLLED DOWN HIS FACE https://t.co/aYuQDPtvsE

# %% [markdown]
# ### male/female_tf contains all the terms with there num of appearnces.

# %%
male_words=uniteLists(data_df['clean_words_list'][data_df['gender'].apply(lambda x: x=='male')])
female_words=uniteLists(data_df['clean_words_list'][data_df['gender'].apply(lambda x: x=='female')])
male_tf = Counter(male_words).most_common()
female_tf=Counter(female_words).most_common()

# %% [markdown]
# ### plot of the num most common terms for male and female

# %%
num=20
fig = plt.figure(figsize=(20,16))
terms,freq=devideToTermsAndFreq(male_tf)
createPlot(terms[:num],freq[:num],'Terms','Number of instances','male tf %s most common'%(num) ,2,1,1,'Accent','barh')
terms,freq=devideToTermsAndFreq(female_tf)
createPlot(terms[:num],freq[:num],'Terms','Number of instances','female tf %s most common'%(num),2,1,2,'Vega10_r','barh')
# Out:
# /usr/local/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: The Vega10_r colormap was deprecated in version 2.0. Use tab10_r instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ### male/female_hashtag_tf contains all the hashtags with there num of appearnces.

# %%
male_hashtag_words=uniteLists(data_df['hashtags'][data_df['gender'].apply(lambda x: x=='male')])
female_hashtag_words=uniteLists(data_df['hashtags'][data_df['gender'].apply(lambda x: x=='female')])
male_hashtag_tf = Counter(male_hashtag_words).most_common()
female_hashtag_tf=Counter(female_hashtag_words).most_common()

# %% [markdown]
# ### plot for num most common #hashtags

# %%
num=20
fig = plt.figure(figsize=(20,16))
terms,freq=devideToTermsAndFreq(male_hashtag_tf)
createPlot(terms[:num],freq[:num],'Terms','Number of instances','male tf %s most common #hashtags'%(num),2,1,1,'tab20c','barh')
terms,freq=devideToTermsAndFreq(female_hashtag_tf)
createPlot(terms[:num],freq[:num],'Terms','Number of instances','female tf %s most common #hashtags'%(num),2,1,2,'tab20b_r','barh')

# %% [markdown]
# ### male/female_emo_tf contains all the emojies with there num of appearnces.

# %%
male_emo_words=uniteLists(data_df['emo'][data_df['gender'].apply(lambda x: x=='male')])
female_emo_words=uniteLists(data_df['emo'][data_df['gender'].apply(lambda x: x=='female')])
male_emo_tf = Counter(male_emo_words).most_common()
female_emo_tf=Counter(female_emo_words).most_common()

# %%
num=15
fig = plt.figure(figsize=(18,16))
terms,freq=devideToTermsAndFreq(male_emo_tf)
createPlot(terms[:num],freq[:num],'emojies','Number of instances','male tf %s most common emojies'%(num),2,1,1,'Set2','barh')
terms,freq=devideToTermsAndFreq(female_emo_tf)
createPlot(terms[:num],freq[:num],'emojies','Number of instances','female tf %s most common emojies'%(num),2,1,2,'Pastel1','barh')

# %% [markdown]
# # /////////////////////////////////////////////////////////////////////////////////////////////////////////

# %% [markdown]
# # Q2
# ## Train a machine learning model to predict the gender of the tweet author

# %%
def changeGenderToNum(word):
    if word=='male':
        return 1 
    return 0
def changeNumToGender(num):
    if num==0:
        return 'female' 
    return 'male'

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import Perceptron
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import cross_val_score

def benchmark(clf,x_train,y_train):
    print('_' * 80)
    print("Training: ")
    print(clf)
    scores = cross_val_score(clf, x_train, y_train, cv=5)
    t0 = time()
    clf.fit(x_train, y_train)
    train_time = time() - t0
    print("train time: %0.3fs" % train_time)

    t0 = time()
    pred = clf.predict(X_test)
    test_time = time() - t0
    print("test time:  %0.3fs" % test_time)

    score = metrics.accuracy_score(Y_test, pred)
    print("CV accuracy:   %0.3f" % scores.mean())
    print("Y_test accuracy:   %0.3f" % score)

    print()
    clf_descr = str(clf).split('(')[0]
    return clf_descr, score, train_time, test_time

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = CountVectorizer(ngram_range=(1,2),lowercase=False)

data_df['num_gender']=data_df['gender'].apply(changeGenderToNum)

test_size=10000

word_for_voc=[]

# for i in data_df['clean_text'].tolist():
#     word_for_voc.append(i)

# for i in data_df['hashtags'].tolist():
#     for j in i:
#         word_for_voc.append(j)
        
# for i in data_df['user_tag'].tolist():
#     for j in i:
#         word_for_voc.append(j)
        
for i in data_df['terms']:
    for j in i:
        word_for_voc.append(j)
        
        
corpus_train=data_df['text'].tolist()[:test_size]

corpus_test=data_df['text'].tolist()[test_size:test_size*2]

vectorizer.fit(word_for_voc)

X_train = vectorizer.transform(corpus_train)
Y_train = data_df['num_gender'][:test_size].tolist()

X_test = vectorizer.transform(corpus_test)
Y_test = data_df['num_gender'][test_size:test_size*2].tolist()

# %%
len(vectorizer.vocabulary_)
len(word_for_voc)
vectorizer.vocabulary_.keys()
# Out:
# dict_keys(['Robbie', 'Responds', 'To', 'Critics', 'After', 'Win', 'Against', 'Eddie', 'Edwards', 'In', 'The', 'WorldTitleSeries', 'https', 'co', 'NSybBmVjKZ', 'ÛÏIt', 'felt', 'like', 'they', 'were', 'my', 'friends', 'and', 'was', 'living', 'the', 'story', 'with', 'them', 'arngE0YHNO', 'retired', 'IAN1', 'CIzCANPQFz', 'absolutely', 'adore', 'when', 'louis', 'starts', 'songs', 'it', 'hits', 'me', 'hard', 'but', 'feels', 'good', 'Hi', 'JordanSpieth', 'Looking', 'at', 'url', 'do', 'you', 'use', 'IFTTT', 'Don', 'typically', 'see', 'an', 'advanced', 'user', 'on', 'PGATOUR', 'H68ou5PE9L', 'Watching', 'Neighbours', 'Sky', 'catching', 'up', 'Neighbs', 'Xxx', '_Ù', 'Ä_Ù', 'Ä_ÙÔÎ_Ù', 'È_ÙÔ', 'Ive', 'seen', 'people', 'train', 'lamps', 'chairs', 'tvs', 'etc', 'w6zf4pVM4I', 'Gala', 'Bingo', 'clubs', 'bought', 'for', '241', 'UK', 'largest', 'High', 'Street', 'bingo', 'operator', 'is', 'being', 'taken', 'over', 'by', 'Û_', 'HzeeykJUd3', '_Aphmau_', 'pic', 'defines', 'all', 'mcd', 'fangirls', 'fanboys', 'shippers', 'xD', 'Evielady', 'just', 'how', 'lovely', 'tree', 'this', 'year', 'Never', 'as', 'gorgeous', 'Autumn', 'colour', 'Just', 'put', 'ass', 'line', 'repay', 'will', 'even', 'need', 'sound', 'effects', 'diviners', 'tonight', 'EROGWTFTYo', 'It', 'glow', 'of', 'satisfaction', 're', 'Glow', '7RdyMCVPKx', 'giannaaa28', 'lmao', 'â_Ù', 'dude', 'hella', 'scared', 'next', 'episode', 'bc', 'ending', 'to', 'yesterday', 'coolyazzy94', 'Ditto', 'still', 'learning', 'favourites', 'retweet', 'stuff', 'least', 'sucks', 'less', 'than', 'Facebook', 'haha', 'CaribBros', 'JstSaleem', 'don', 'understand', 'get', 'server', 'CraftYear2015', 'isabelpascual', 'thank', 'retweets', 'All', 'girls', 'went', 'sleep', 'guys', 'sat', 'in', 'floor', 'watched', 'us_Ù', 'ChrisAOfficial', 'right', 'side', 'ÏÎ_Ù', 'xxx', 'YALL', 'LMFAOO', 'RIGHT', 'WHEN', 'THE', 'CHORUS', 'CAME', 'ON', 'TEAR', 'ROLLED', 'DOWN', 'HIS', 'FACE', 'aYuQDPtvsE', 'James', 'Bond', 'premier', 'night', 'Everymancinema', 'Oxted', 'SidiEdey', 'Let', 'hope', 'lives', 'expectation', 'SPECTRE', 'SydnieJR', 'except', 'once', 'Hallmark', 'movies', 'start', 'won', 'anything', 'done', '__Ù_', '_Ù_ã', 'You', 'leave', 'group', 'chat', 'more', 'mins', 'miss', 'made', 'shit', 'As', 'opposed', 'Pump', 'where', 'HI', 'HOPE', 'YOU', 'LIKE', 'DOING', 'JUMPS', 'WHERE', 'SPREAD', 'YOUR', 'FEET', 'ACROSS', 'ENTIRE', 'STAGE', 'magic', 'Hath', 'No', 'FURY', 'based', 'REAL', 'Magick', 'jwpsVhAU1E', 'Me', 'week', 'Brandon', 'birthday', 'there', 'no', 'such', 'thing', 'weirdo', 'November', 'st', 'month', 'bow', 'down', 'And', 'got', 'yards', 'AND', 'points', 'Jets', 'gave', 'season', 'gdfkaOxcDD', 'Did', 'Alot', 'Up', 'Past', 'Ion', 'Wont', 'Back', 'This', 'boy', 'El', 'wit', 'his', 'daughters', 'under', 'TheRiddler109', 'CNN', 'mean', 'not', 'Mainstream', 'new', 'media', 'supposed', 'feed', 'fact', 'nowadays', 'How', 'many', 'followers', 'everyday', 'last', 'day', 'Growing', 'daily', 'JzckR3ub8H', 'onedirection', 'Artist', 'Year', 'AMAs', 'HO', 'FAME', 'kbonimtetezi', 'mheshimiwa', 'travellers', 'along', 'that', 'stretch', 'road', 'lubao', 'hurting', 'nobody', 'seems', 'be', 'raising', 'issue', 'Greenville', 'Thursday', 'Yall', 'holla', 'Know', 'plug', 'MarkHicks1204', 'wrong', 'Nandos', 'found', 'eventually', '10chilliesequalsfreenandos', 'AndyRobsonTips', 'Cardiff', 'or', 'drew', 'match', 'goals', 'sounds', 'Those', 'who', 'break', 'rules', 'are', 'scum', 'those', 'abandon', 'their', 'worse', 'XprInke1m2', 'VIDEO', 'Spectre', 'world', 'premiere', 'months', 'build', 'latest', 'uV38Wlg5bE', 'Best', 'about', 'having', 'audition', 'west', 'able', 'eat', 'lunch', 'Komodo', 'Discipline', 'bridge', 'between', 'accomplishment', 'Jim', 'Rohn', '20', 'minutes', 'Wednesday', 'fan', 'has', 'tweeted', 'us', 'times', 'obsessed', 'little', 'bit', 'Once', 'complete', 'lift', 'off', 'attempt', 'connect', 'alpha', 'point', 'rift', 'we', 'observing', 'Triggered', 'Email', 'Killer', 'Conversion', 'App', 'obCkhxkOm7', 'camerons', 'bed', 'sme ...

# %%
results = []

SVM=SGDClassifier()
NB=MultinomialNB()
KN=KNeighborsClassifier(15)
for clf, name in (
        (SVM,"SVM"),
        (KN, "kneighbors"),
        (NB,"Naive Bayes")
    ):
    print('=' * 80)
    print(name)
    results.append(benchmark(clf,X_train,Y_train))
# Out:
# ================================================================================
# SVM
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', max_iter=None, n_iter=None,
#        n_jobs=1, penalty='l2', power_t=0.5, random_state=None,
#        shuffle=True, tol=None, verbose=0, warm_start=False)
# train time: 0.009s
# test time:  0.001s
# CV accuracy:   0.567
# Y_test accuracy:   0.589
#
# ================================================================================
# kneighbors
# ________________________________________________________________________________
# Training:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=15, p=2,
#            weights='uniform')
# /usr/local/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /usr/local/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /usr/local/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /usr/local/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /usr/local/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# train time: 0.002s
# test time:  3.092s
# CV accuracy:   0.524
# Y_test accuracy:   0.563
#
# ================================================================================
# Naive Bayes
# ________________________________________________________________________________
# Training:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)
# train time: 0.006s
# test time:  0.001s
# CV accuracy:   0.598
# Y_test accuracy:   0.628

# %%
X_train=X_train.toarray()
Y_train=np.asarray(Y_train)
X_test=X_test.toarray()
Y_test=np.asarray(Y_test)

# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy
# fix random seed for reproducibility
numpy.random.seed(7)
# split into input (X) and output (Y) variables
# create model

model = Sequential()
model.add(Dense(X_train.shape[0], input_shape=(X_train.shape[1],), activation='relu'))
model.add(Dense(X_train.shape[0], activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Compile model
model.compile(loss='mean_squared_error', optimizer='sgd', metrics=['accuracy'])
# Fit the model
model.fit(X_train, Y_train, epochs=3, batch_size=50)
# evaluate the model
scores = model.evaluate(X_test, Y_test)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))

# %%
changeNumToGender(SVM.predict(vectorizer.transform(['there is a football game this monday']).toarray())[0])
# Out:
# 'male'

# %% [markdown]
# ## Get most tweeted country

# %%
locations = data_df['tweet_location'][data_df['tweet_location'].apply(lambda x: type(x) == str)]
locations=locations.apply(clean)
locations_tf = Counter(locations).most_common()
locations_tf
# Out:
# [('london', 120),
#  ('los angeles ca', 57),
#  ('uk', 53),
#  ('united state', 50),
#  ('los angeles', 46),
#  ('new york', 41),
#  ('lagos nigeria', 38),
#  ('london england', 36),
#  ('', 36),
#  ('nyc', 34),
#  ('chicago il', 33),
#  ('atlanta ga', 33),
#  ('usa', 32),
#  ('texas', 32),
#  ('california', 32),
#  ('boston', 31),
#  ('canada', 31),
#  ('new york ny', 30),
#  ('chicago', 30),
#  ('united kingdom', 29),
#  ('washington dc', 28),
#  ('houston tx', 26),
#  ('austin tx', 26),
#  ('england', 25),
#  ('toronto', 25),
#  ('san francisco ca', 21),
#  ('england united kingdom', 21),
#  ('manchester', 20),
#  ('philadelphia pa', 20),
#  ('florida', 19),
#  ('\x89ã\x8farry laura \x88â»\x88âò', 19),
#  ('scotland', 18),
#  ('new york city', 18),
#  ('ohio', 17),
#  ('seattle wa', 17),
#  ('atlanta', 16),
#  ('nigeria', 15),
#  ('earth', 15),
#  ('brooklyn ny', 15),
#  ('seattle', 15),
#  ('glasgow', 14),
#  ('charlotte nc', 14),
#  ('italy', 14),
#  ('michigan', 14),
#  ('houston', 14),
#  ('denver co', 14),
#  ('ireland', 13),
#  ('lagos', 13),
#  ('birmingham', 13),
#  ('london uk', 13),
#  ('south africa', 12),
#  ('cape town south africa', 12),
#  ('johannesburg south africa', 12),
#  ('dallas tx', 12),
#  ('florida usa', 12),
#  ('nashville tn', 12),
#  ('california usa', 12),
#  ('australia', 12),
#  ('germany', 11),
#  ('orlando fl', 11),
#  ('los angeles california', 11),
#  ('north carolina', 11),
#  ('san francisco', 11),
#  ('new york usa', 11),
#  ('san antonio tx', 11),
#  ('la vega nv', 11),
#  ('sacramento ca', 10),
#  ('buffalo ny', 10),
#  ('dublin', 10),
#  ('worldwide', 10),
#  ('louisville ky', 10),
#  ('manchester uk', 10),
#  ('phoenix az', 10),
#  ('porto portugal \x89ñùí \x89ñ í', 10),
#  ('1 16 cute pickle peeling squad', 10),
#  ('ny', 9),
#  ('pittsburgh pa', 9),
#  ('montreal', 9),
#  ('toronto canada', 9),
#  ('columbus oh', 9),
#  ('nairobi kenya', 9),
#  ('planet earth', 9),
#  ('virginia', 9),
#  ('access lilo 4 \x89û¢ dani', 9),
#  ('vancouver british columbia', 9),
#  ('houston texas', 9),
#  ('atl', 9),
#  ('san diego ca', 9),
#  ('brooklyn', 9),
#  ('toronto ontario', 9),
#  ('miami fl', 9),
#  ('india', 9),
#  ('portland', 9),
#  ('new jersey', 9),
#  ('minnesota', 9),
#  ('tampa fl', 8),
#  ('queen ny', 8),
#  ('neverland', 8),
#  ('philadelphia', 8),
#  ('worcester', 8),
#  ('wale', 8),
#  ('bristol', 8),
#  ('dmv', 8),
#  ('wonderland', 8),
#  ('georgia', 8),
#  ('kansa city mo', 8),
#  ('michigan usa', 8),
#  ('new york new york', 8),
#  ('leeds', 8),
#  ('new orleans la', 7),
#  ('jakarta indonesia', 7),
#  ('wisconsin', 7),
#  ('dallas', 7),
#  ('nj', 7),
#  ('milwaukee wi', 7),
#  ('indonesia', 7),
#  ('north carolina usa', 7),
#  ('detroit mi', 7),
#  ('oklahoma', 7),
#  ('dublin ireland', 7),
#  ('virginia usa', 7),
#  ('everywhere', 7),
#  ('cape town', 7),
#  ('finland', 7),
#  ('portland oregon', 7),
#  ('la', 7),
#  ('indianapolis', 7),
#  ('san diego', 7),
#  ('nc', 7),
#  ('cambridge', 7),
#  ('indiana', 7),
#  ('la vega', 7),
#  ('glasgow scotland', 7),
#  ('texas usa', 7),
#  ('belgium', 7),
#  ('maryland', 7),
#  ('pretoria', 7),
#  ('pa', 7),
#  ('norwich', 7),
#  ('\x89ªá\x89ªá\x89ªá dementia town \x89ªá\x89ªá\x89ªá', 7),
#  ('mina gerais brasil', 7),
#  ('manhattan ny', 6),
#  ('scotland united kingdom', 6),
#  ('utah', 6),
#  ('madrid', 6),
#  ('baltimore md', 6),
#  ('fl', 6),
#  ('brasil', 6),
#  ('colorado', 6),
#  ('edmonton alberta', 6),
#  ('world', 6),
#  ('sydney australia', 6),
#  ('kentucky', 6),
#  ('3 4 band', 6),
#  ('georgia usa', 6),
#  ('new orleans', 6),
#  ('manchester england', 6),
#  ('alberta canada', 6),
#  ('sheffield england', 6),
#  ('vancouver bc', 6),
#  ('pennsylvania', 6),
#  ('birmingham uk', 6),
#  ('derbyshire', 6),
#  ('cleveland oh', 6),
#  ('brighton', 6),
#  ('southampton', 6),
#  ('france', 6),
#  ('brazil', 6),
#  ('minneapolis mn', 6),
#  ('kent', 6),
#  ('oakland ca', 6),
#  ('bay area', 6),
#  ('san jose ca', 6),
#  ('louisiana', 6),
#  ('johannesburg', 6),
#  ('colorado spring co', 6),
#  ('miami', 6),
#  ('edinburgh scotland', 6),
#  ('arizona', 6),
#  ('richmond va', 6),
#  ('wale united kingdom', 6),
#  ('liverpool', 6),
#  ('essex', 6),
#  ('chez zayn malik', 6),
#  ('nottingham england', 5),
#  ('venezuela', 5),
#  ('washington d c', 5),
#  ('melbourne australia', 5),
#  ('tx', 5),
#  ('turkey', 5),
#  ('orlando florida', 5),
#  ('arlington va', 5),
#  ('sweden', 5),
#  ('st louis mo', 5),
#  ('new zealand', 5),
#  ('raleigh nc', 5),
#  ('amsterdam', 5),
#  ('pakistan', 5),
#  ('liverpool england', 5),
#  ('ontario canada', 5),
#  ('new jersey usa', 5),
#  ('philippine', 5),
#  ('netherlands', 5),
#  ('melanie martinez \x89ªá', 5),
#  ('memphis tn', 5),
#  ('ca', 5),
#  ('tampa', 5),
#  ('badlands', 5),
#  ('edinburgh', 5),
#  ('honeymoon ì£ve', 5),
#  ('south west england', 5),
#  ('denmark', 5),
#  ('argentina', 5),
#  ('cairo egypt', 5),
#  ('honolulu hi', 5),
#  ('ottawa ontario', 5),
#  ('massachusetts usa', 5),
#  ('brighton england', 5),
#  ('jersey', 5),
#  ('illinois', 5),
#  ('vancouver', 5),
#  ('belfast', 5),
#  ('mar', 5),
#  ('kansa city', 5),
#  ('missouri', 5),
#  ('fort worth tx', 5),
#  ('wiltshire', 5),
#  ('karachi pakistan', 5),
#  ('republic philippine', 5),
#  ('surrey', 4),
#  ('pennsylvania usa', 4),
#  ('mumbai maharashtra', 4),
#  ('mexico city', 4),
#  ('northern california', 4),
#  ('trinidad tobago', 4),
#  ('melbourne', 4),
#  ('dunder mifflin', 4),
#  ('jackson m', 4),
#  ('here', 4),
#  ('washington usa', 4),
#  ('long island', 4),
#  ('bronx ny', 4),
#  ('america', 4),
#  ('kalamazoo mi', 4),
#  ('sheffield', 4),
#  ('surprise az', 4),
#  ('massachusetts', 4),
#  ('greensboro nc', 4),
#  ('dubai uae', 4),
#  ('global', 4),
#  ('singapore', 4),
#  ('mumbai', 4),
#  ('paris', 4),
#  ('st louis', 4),
#  ('yorkshire', 4),
#  ('new hampshire', 4),
#  ('oakland', 4),
#  ('basingstoke', 4),
#  ('boca raton fl', 4),
#  ('illinois usa', 4),
#  ('ottawa', 4),
#  ('they them', 4),
#  ('omaha ne', 4),
#  ('east lansing mi', 4),
#  ('blacklivesmatter', 4),
#  ('orange county ca', 4),
#  ('hell', 4),
#  ('fort worth texas', 4),
#  ('il', 4),
#  ('nottingham', 4),
#  ('mumbai india', 4),
#  ('rotherham', 4),
#  ('pittsburgh', 4),
#  ('north west england', 4),
#  ('jacksonville fl', 4),
#  ('queen new york', 4),
#  ('kuwait', 4),
#  ('auckland new zealand', 4),
#  ('west london', 4),
#  ('united state america', 4),
#  ('buenos aire argentina', 4),
#  ('newcastle', 4),
#  ('fargo nd', 4),
#  ('bc canada', 4),
#  ('saint louis', 4),
#  ('islamabad', 4),
#  ('lancashire', 4),
#  ('mi', 4),
#  ('sydney', 4),
#  ('cleveland ohio', 4),
#  ('ohio usa', 4),
#  ('denver', 4),
#  ('dallas texas', 4),
#  ('poland', 4),
#  ('southampton uk', 4),
#  ('new mexico', 4),
#  ('northampton', 3),
#  ('place', 3),
#  ('arkansas', 3),
#  ('salt lake city utah', 3),
#  ('bakersfield ca', 3),
#  ('cali', 3),
#  ('santa barbara ca', 3),
#  ('gym', 3),
#  ('milton keynes', 3),
#  ('cornwall', 3),
#  ('lawrence k', 3),
#  ('halloweentown', 3),
#  ('tx ny', 3),
#  ('wilmington nc', 3),
#  ('peterborough england', 3),
#  ('south east england', 3),
#  ('brooklyn new york', 3),
#  ('durban south africa', 3),
#  ('hampshire', 3),
#  ('maine', 3),
#  ('south', 3),
#  ('stockholm', 3),
#  ('dublin city ireland', 3),
#  ('montreal canada', 3),
#  ('she her', 3),
#  ('reading', 3),
#  ('galaxy far far away', 3),
#  ('dc', 3),
#  ('washington dc area', 3),
#  ('la capital argentina', 3),
#  ('hampshire uk', 3),
#  ('socal', 3),
#  ('home', 3),
#  ('dubai', 3),
#  ('switzerland', 3),
#  ('egypt', 3),
#  ('east london', 3),
#  ('gainesville fl', 3),
#  ('belfast northern ireland', 3),
#  ('wirral england', 3),
#  ('kampala uganda', 3),
#  ('bangalore', 3),
#  ('u', 3),
#  ('northern ireland', 3),
#  ('tucson az', 3),
#  ('olympia wa', 3),
#  ('westeros', 3),
#  ('bristol england', 3),
#  ('az', 3),
#  ('corpus christi', 3),
#  ('pensacola fl', 3),
#  ('iowa', 3),
#  ('colchester', 3),
#  ('polska', 3),
#  ('calgary alberta canada', 3),
#  ('medina', 3),
#  ('maldives', 3),
#  ('cambridge uk', 3),
#  ('charlotte', 3),
#  ('staten island ny', 3),
#  ('wildest dream', 3),
#  ('6 feb', 3),
#  ('slovakia', 3),
#  ('dubai united arab emirate', 3),
#  ('moon', 3),
#  ('malaysia', 3),
#  ('athens greece', 3),
#  ('k town', 3),
#  ('palmdale ca', 3),
#  ('colorado usa', 3),
#  ('kenya', 3),
#  ('champaign il', 3),
#  ('she they', 3),
#  ('u k', 3),
#  ('ga', 3),
#  ('columbia mo', 3),
#  ('halifax nova scotia', 3),
#  ('hyrule', 3),
#  ('boise id', 3),
#  ('los angeles new york', 3),
#  ('plymouth', 3),
#  ('boston homocide', 3),
#  ('san antonio texas', 3),
#  ('nairobi', 3),
#  ('philly', 3),
#  ('shropshire', 3),
#  ('rio de janeiro brasil', 3),
#  ('washington', 3),
#  ('leicester', 3),
#  ('china', 3),
#  ('al tn', 3),
#  ('liverpool uk', 3),
#  ('red carpet', 3),
#  ('bolton', 3),
#  ('abuja nigeria', 3),
#  ('corona ca', 3),
#  ('malta', 3),
#  ('williamsburg va', 3),
#  ('huddersfield', 3),
#  ('europe', 3),
#  ('lahore', 3),
#  ('sf bay area', 3),
#  ('evansville', 3),
#  ('bedford england', 3),
#  ('utah usa', 3),
#  ('coventry england', 3),
#  ('suplex city', 3),
#  ('seattle washington', 3),
#  ('lebanon', 3),
#  ('paris france', 3),
#  ('portugal', 3),
#  ('limbo', 3),
#  ('manila philippine', 3),
#  ('calgary ab canada', 3),
#  ('l n', 3),
#  ('connecticut usa', 3),
#  ('bristol uk', 3),
#  ('connecticut', 3),
#  ('st louis missouri', 3),
#  ('pre order made', 3),
#  ('hogwarts', 3),
#  ('long island ny', 3),
#  ('bay area ca', 3),
#  ('chertsey bridge', 3),
#  ('fort collins co', 3),
#  ('london united kingdom', 3),
#  ('suffolk', 3),
#  ('missouri usa', 3),
#  ('durham', 3),
#  ('doha qatar', 3),
#  ('sì£o paulo brasil', 3),
#  ('british columbia canada', 3),
#  ('dc metro', 3),
#  ('atlanta georgia', 3),
#  ('lv', 3),
#  ('dianixer\x89ªá isistas\x89ªá ferlove', 3),
#  ('paradise', 3),
#  ('mnl', 3),
#  ('\x89 ÷cìé\x84ó ü\x84âë± ìô®õ®õ\x83»c\x83»ë±i\x89 ð', 3),
#  ('palo alto ca', 2),
#  ('st john s newfoundland', 2),
#  ('edmond ok', 2),
#  ('waterford ireland', 2),
#  ('\x89ãü everything \x88 \x89ï¤\x88 ô', 2),
#  ('127 0 0 1', 2),
#  ('kalu blackedout co uk', 2),
#  ('university', 2),
#  ('torres nova', 2),
#  ('newcastle upon tyne england', 2),
#  ('santo domingo', 2),
#  ('santa cruz ca', 2),
#  ('anywhere', 2),
#  ('dayton oh', 2),
#  ('waco tx', 2),
#  ('rva', 2),
#  ('long beach', 2),
#  ('cranfield uk', 2),
#  ('chennai', 2),
#  ('delaware', 2),
#  ('tunisie', 2),
#  ('east harlem nyc', 2),
#  ('oceanside ca', 2),
#  ('anderson sc', 2),
#  ('sarasota fl', 2),
#  ('610', 2),
#  ('jersey city nj', 2),
#  ('newark nj', 2),
#  ('outh central la', 2),
#  ('chicago chirilla south side', 2),
#  ('918', 2),
#  ('heart', 2),
#  ('deutschland', 2),
#  ('bellingham wa', 2),
#  ('jefferson city missouri', 2),
#  ('weymouth', 2),
#  ('miami florida', 2),
#  ('pa usa', 2),
#  ('unknown', 2),
#  ('mexico', 2),
#  ('l ìäcosse libre scotland', 2),
#  ('cleveland', 2),
#  ('battle creek mi', 2),
#  ('peterborough', 2),
#  ('rgf island', 2),
#  ('parabatai cubed \x89 ¡ 1 brook fan', 2),
#  ('instagram destructiblee', 2),
#  ('cary nc', 2),
#  ('hull', 2),
#  ('israel', 2),
#  ('ontario ca', 2),
#  ('edmonton ab', 2),
#  ('vega', 2),
#  ('universe', 2),
#  ('hartlepool', 2),
#  ('tn', 2),
#  ('dtw \x89ïö grr', 2),
#  ('413', 2),
#  ('colombo sri lanka', 2),
#  ('columbus ohio', 2),
#  ('vancouver canada', 2),
#  ('staffordshire uk', 2),
#  ('buffalo new york', 2),
#  ('west yorkshire uk', 2),
#  ('newport beach ca', 2),
#  ('joplin mo', 2),
#  ('middle bloody wood', 2),
#  ('durham england', 2),
#  ('devon', 2),
#  ('mafikeng', 2),
#  ('north charleston sc', 2),
#  ('columbia sc', 2),
#  ('east yorkshire', 2),
#  ('venice', 2),
#  ('wylie tx', 2),
#  ('hull england', 2),
#  ('pizza planet', 2),
#  ('lost', 2),
#  ('losangeles ca', 2),
#  ('burnaby british columbia', 2),
#  ('winelands cape town', 2),
#  ('al', 2),
#  ('star', 2),
#  ('somewhere rainbow', 2),
#  ('rio grande sul brasil', 2),
#  ('garden state', 2),
#  ('fredericton nb', 2),
#  ('cash me imperatorb', 2),
#  ('san diego county', 2),
#  ('bikini bottom', 2),
#  ('gaborone botswana', 2),
#  ('see question mercury', 2),
#  ('kaylee 16 she her', 2),
#  ('dallas texas hold em', 2),
#  ('watford hertfordshire', 2),
#  ('kolkata', 2),
#  ('bournemouth', 2),
#  ('member backyard murder', 2),
#  ('lusaka zambia', 2),
#  ('stamford bridge ojuelegba', 2),
#  ('new york london', 2),
#  ('buena vista co 81211', 2),
#  ('dm v', 2),
#  ('newcastle england', 2),
#  ('here there everywhere', 2),
#  ('h town mo city', 2),
#  ('world wide web', 2),
#  ('milwaukee', 2),
#  ('charlottesville va', 2),
#  ('\x95 á\x95 \x95 ª\x95 ñ\x95 ö\x95 é\x95 õ\x95 é \x95 © \x95 á\x95 \x81\x95 \x95 ó',
#   2),
#  ('taunton', 2),
#  ('kansa usa', 2),
#  ('london uk new york usa', 2),
#  ('paris ile de france', 2),
#  ('shreveport la', 2),
#  ('scarborough england', 2),
#  ('sussex london kent hampshire', 2),
#  ('chì£o', 2),
#  ('wichita k', 2),
#  ('san antonio', 2),
#  ('ashland ohio', 2),
#  ('dunfermline scotland', 2),
#  ('colombia', 2),
#  ('rochester ny', 2),
#  ('brussels belgium', 2),
#  ('bournemouth england', 2),
#  ('almeria spain', 2),
#  ('lisboa portugal', 2),
#  ('nashville', 2),
#  ('nairobi\x89ã¢ kenya\x89ñ', 2),
#  ('oklahoma city ok', 2),
#  ('plymouth england', 2),
#  ('ottawa ontario canada', 2),
#  ('huntsville al', 2),
#  ('dorchester', 2),
#  ('jacksonville beach fl', 2),
#  ('757', 2),
#  ('fort lauderdale fl', 2),
#  ('soweto', 2),
#  ('part unknown', 2),
#  ('heaven', 2),
#  ('athens oh', 2),
#  ('san francisco ca usa', 2),
#  ('county durham', 2),
#  ('mississauga ontario', 2),
#  ('cincinnati', 2),
#  ('toronto ontario canada', 2),
#  ('cheshire', 2),
#  ('milan italy', 2),
#  ('long beach ca', 2),
#  ('wellington nz', 2),
#  ('htx', 2),
#  ('indiana usa', 2),
#  ('grimsby england', 2),
#  ('alabama usa', 2),
#  ('san francisco bay area', 2),
#  ('rexford ny', 2),
#  ('money major issue', 2),
#  ('ìït 40 288708 74 292437', 2),
#  ('wolverhampton', 2),
#  ('pdx', 2),
#  ('valencia spain', 2),
#  ('statesville nc', 2),
#  ('global check free', 2),
#  ('sì£o paulo brazil', 2),
#  ('durban', 2),
#  ('islamabad pakistan', 2),
#  ('sweet home alabama', 2),
#  ('name', 2),
#  ('fairfield ca', 2),
#  ('msu', 2),
#  ('japan', 2),
#  ('chilling', 2),
#  ('baltimore', 2),
#  ('greenville sc', 2),
#  ('salt lake city ut', 2),
#  ('left coast', 2),
#  ('lahore pakistan', 2),
#  ('southern california', 2),
#  ('riverside ca', 2),
#  ('mia', 2),
#  ('bed', 2),
#  ('chicagoland', 2),
#  ('0 4', 2),
#  ('camp blueberry ef', 2),
#  ('mn', 2),
#  ('potato land', 2),
#  ('galway ireland', 2),
#  ('san diego california', 2),
#  ('leeds england', 2),
#  ('dream', 2),
#  ('venus', 2),
#  ('h 4 soon', 2),
#  ('wanna be', 2),
#  ('south bend', 2),
#  ('state college pa', 2),
#  ('puerto rico', 2),
#  ('west midland', 2),
#  ('new orleans louisiana', 2),
#  ('kalamazoo michigan', 2),
#  ('hartford ct', 2),
#  ('kampala', 2),
#  ('john island sc', 2),
#  ('bhx', 2),
#  ('dundee', 2),
#  ('huntington beach ca', 2),
#  ('north london', 2),
#  ('irmo sc', 2),
#  ('rancho cucamonga california', 2),
#  ('w\x84ó ë±r\x84ó h\x84ór\x84ó tìä cr\x84óë±t\x84ó', 2),
#  ('alagbado lagos', 2),
#  ('halifax', 2),
#  ('stamford ct', 2),
#  ('nj ny', 2),
#  ('south carolina', 2),
#  ('newcastle upon tyne', 2),
#  ('texas hill country', 2),
#  ('corner', 2),
#  ('saudi arabia', 2),
#  ('caribbean', 2),
#  ('northwest arkansas', 2),
#  ('tennessee usa', 2),
#  ('pnw', 2),
#  ('amsterdam north holland', 2),
#  ('exeter', 2),
#  ('mesa az', 2),
#  ('south dakota', 2),
#  ('ibadan oyo state', 2),
#  ('trumbull connecticut usa', 2),
#  ('aberdeen scotland', 2),
#  ('tulsa ok', 2),
#  ('honolulu hawaii', 2),
#  ('buckinghamshire', 2),
#  ('derbyshire uk', 2),
#  ('detroit', 2),
#  ('reno nv', 2),
#  ('somewhere europe', 2),
#  ('knoxville tn', 2),
#  ('around world', 2),
#  ('keller tx', 2),
#  ('middlesbrough', 2),
#  ('305', 2),
#  ('ball state university', 2),
#  ('washington township nj', 2),
#  ('rhode island usa', 2),
#  ('upstate ny', 2),
#  ('sunderland', 2),
#  ('guatemala', 2),
#  ('8 5 14', 2),
#  ('gy uk', 2),
#  ('coventry', 2),
#  ('pasadena maryland', 2),
#  ('portsmouth', 2),
#  ('ville', 2),
#  ('somewhere neverland', 2),
#  ('cedar rapid iowa', 2),
#  ('athens ga', 2),
#  ('england uk', 2),
#  ('fayetteville ar', 2),
#  ('port elizabeth south africa', 2),
#  ('lawrenceville ga', 2),
#  ('la nyc', 2),
#  ('christchurch new zealand', 2),
#  ('denver colorado', 2),
#  ('uganda', 2),
#  ('rotterdam netherlands', 2),
#  ('kolkata west bengal', 2),
#  ('hertfordshire england', 2),
#  ('murfreesboro tn', 2),
#  ('searching', 2),
#  ('aberdeen', 2),
#  ('new york augusta', 2),
#  ('florence alabama', 2),
#  ('king george va', 2),
#  ('lancaster pa', 2),
#  ('naperville il', 2),
#  ('loughborough england', 2),
#  ('oregon', 2),
#  ('maryland usa', 2),
#  ('lincoln nebraska', 2),
#  ('raleigh north carolina', 2),
#  ('suomi finland', 2),
#  ('burlington ontario', 2),
#  ('ocala florida', 2),
#  ('trench', 2),
#  ('nashville tennessee', 2),
#  ('santa clara ca', 2),
#  ('è è kate \x8bûû\x89ï \x8bûû', 2),
#  ('westcoast', 2),
#  ('bullshit zone', 2),
#  ('red bay alabama', 2),
#  ('prolly wit ya bitch', 2),
#  ('cam bed', 2),
#  ('chiraq', 2),
#  ('davis ca', 2),
#  ('candyland', 2),
#  ('citizen world', 2),
#  ('oklahoma usa', 2),
#  ('great lake state', 2),
#  ('holmes chapel england', 2),
#  ('vancouver bc canada', 2),
#  ('louisville', 2),
#  ('kianjc 0 3 magcon 1 15', 2),
#  ('dreamville', 2),
#  ('warrington', 2),
#  ('ksu 19', 2),
#  ('germany owl', 2),
#  ('milan brussels airplane', 2),
#  ('va', 2),
#  ('st charles', 2),
#  ('south carolina usa', 2),
#  ('god county', 2),
#  ('barcelona', 2),
#  ('tom river nj', 2),
#  ('dmv irginia', 2),
#  ('danmark', 2),
#  ('nyc lima', 2),
#  ('amherst ny', 2),
#  ('winnipeg', 2),
#  ('austin texas', 2),
#  ('6ix', 2),
#  ('trap near you', 2),
#  ('mobile al', 2),
#  ('snapchat atwins420 å©2015', 2),
#  ('864', 2),
#  ('c h c g', 2),
#  ('caerdydd cardiff cymru wale', 2),
#  ('scumrise', 2),
#  ('br \x89û¢ \x89ªò \x89û¢ infp \x89û¢ eng pt', 2),
#  ('web pack tuition', 2),
#  ('northern virginia', 2),
#  ('\x80îeskìá republika', 2),
#  ('derby england', 2),
#  ('spokane wa', 2),
#  ('south boston', 2),
#  ('orange county california', 2),
#  ('bangalore manipal gurgaon', 2),
#  ('masshole', 2),
#  ('bama \x89÷û\x95ü\x8f', 2),
#  ('tampa bay', 2),
#  ('alcoamurai dojo', 2),
#  ('verona \x89ªá', 2),
#  ('mind', 2),
#  ('dph 16', 2),
#  ('rp', 2),
#  ('gay ship tv show anime', 2),
#  ('ìït 34 031175 117 944271', 2),
#  ('trap house', 2),
#  ('istanbul', 2),
#  ('wandering', 2),
#  ('he him', 2),
#  ('uk \x89û¢ sunshine 4 \x89û¢ soph mine', 2),
#  ('royal rainbow', 2),
#  ('new hampshire usa', 2),
#  ('pacific northwest', 2),
#  ('brisbane australia', 2),
#  ('lima perì¼', 2),
#  ('hertfordshire', 2),
#  ('virginia beach va', 2),
#  ('crawley england', 2),
#  ('anywhere world', 2),
#  ('somerset', 2),
#  ('fairy garden', 2),
#  ('cardiff wale uk', 2),
#  ('leicester uk', 2),
#  ('greece', 2),
#  ('broken arrow ok', 2),
#  ('lebanon nh', 2),
#  ('lima peru', 2),
#  ('pasadena ca', 2),
#  ('goddammitthisisamerica', 2),
#  ('garland texas', 2),
#  ('burmingum uk dudley really', 2),
#  ('fort lauderdale florida', 2),
#  ('los angeles calif', 2),
#  ('ìït 26 1976462 28 0312431', 2),
#  ('eureka ca', 2),
#  ('tangled great escape', 2),
#  ('\x89ªómary tom s kingdom\x89ªó', 2),
#  ('east new orleans louisiana', 2),
#  ('h', 2),
#  ('jakarta', 2),
#  ('cloud9\x89ä£', 2),
#  ('chennai india', 2),
#  ('lafayette la', 2),
#  ('karachi', 2),
#  ('big canoe georgia', 2),
#  ('snapchat daemontana103rd', 2),
#  ('cape coral fl', 2),
#  ('rip jackson tanner', 2),
#  ('bath uk', 2),
#  ('hull manchester uk', 2),
#  ('stay fly\x89ªá', 2),
#  ('jax fla', 2),
#  ('newcastle australia', 2),
#  ('narnia', 2),
#  ('anchorage ak', 2),
#  ('riverside california', 2),
#  ('bone', 2),
#  ('afghanistan', 2),
#  ('ìït 43 182918 77 651224', 2),
#  ('pdx wonksaggin', 2),
#  ('anywhere money', 2),
#  ('amherst', 2),
#  ('fresno ca', 2),
#  ('roanoke va', 2),
#  ('cork', 2),
#  ('salt lake city', 2),
#  ('israel vegan', 2),
#  ('brightwood park d c', 2),
#  ('denton texas', 2),
#  ('stl', 2),
#  ('concord nc', 2),
#  ('jackson jimin michael', 2),
#  ('stockholm sweden', 2),
#  ('sheffield uk', 2),
#  ('8 25 15', 2),
#  ('oxford uk', 2),
#  ('gosforth newcastle upon tyne', 2),
#  ('north', 2),
#  ('see broadway', 2),
#  ('stamford bridge', 2),
#  ('beaumont tx', 2),
#  ('burleson texas', 2),
#  ('empire', 2),
#  ('storybrooke maine', 2),
#  ('south lake tahoe ca', 2),
#  ('katy tx', 2),
#  ('abuja', 2),
#  ('north wale', 2),
#  ('coxa harry', 2),
#  ('rushden', 2),
#  ('new york barcelona', 2),
#  ('baleau', 2),
#  ('twin city mn', 2),
#  ('u s a', 2),
#  ('barberville', 2),
#  ('port st lucie fl', 2),
#  ('birmingham england', 2),
#  ('new york city ny', 2),
#  ('idol follows', 2),
#  ('cincinnati ohio', 2),
#  ('zurich switzerland', 2),
#  ('lexington ky', 2),
#  ('bedford tx', 2),
#  ('albania', 2),
#  ('newquay', 2),
#  ('houston texas usa', 2),
#  ('winnipeg mb', 2),
#  ('zone18', 2),
#  ('derby', 2),
#  ('804', 2),
#  ('federal republic naija', 2),
#  ('tennessee', 2),
#  ('iowa city ia', 2),
#  ('slc', 2),
#  ('oxford m', 2),
#  ('new york city los angeles', 2),
#  ('swansea wale', 2),
#  ('romford', 2),
#  ('sankt gallen schweiz', 2),
#  ('looking', 2),
#  ('ldn', 2),
#  ('west palm beach fl', 2),
#  ('new delhi', 2),
#  ('main kan1shk3', 1),
#  ('clcncl', 1),
#  ('new york gritty', 1),
#  ('row b seat 104', 1),
#  ('port au prince', 1),
#  ('university surrey', 1),
#  ('icon aogiri penta', 1),
#  ('princeton', 1),
#  ('algonac mt pleasant mi', 1),
#  ('brittany s mouth panty', 1),
#  ('dazhane s \x89ªá', 1),
#  ('maven severed', 1),
#  ('italy naples', 1),
#  ('candied island', 1),
#  ('sabah', 1),
#  ('gaia', 1),
#  ('north side london', 1),
#  ('wright anything agency', 1),
#  ('¯¬ô ¯» ¯£ôàôãô', 1),
#  ('practicing kindness', 1),
#  ('greenville s c', 1),
#  ('pronoun dead pool', 1),
#  ('belleville', 1),
#  ('spncw samandriels', 1),
#  ('bay area x boulder', 1),
#  ('west cornwall', 1),
#  ('napoli campania', 1),
#  ('palmerston north foxton', 1),
#  ('rolling gang 20', 1),
#  ('somewhere small pa', 1),
#  ('julos midi pyrì©nì©es', 1),
#  ('harbor spring mi', 1),
#  ('okc', 1),
#  ('chicago \x89ï¬', 1),
#  ('beirut', 1),
#  ('southern utah', 1),
#  ('nigeria abuja', 1),
#  ('brooklyn wat look like', 1),
#  ('hampton va', 1),
#  ('43 122580 87 914122', 1),
#  ('richmond', 1),
#  ('coppinstate19', 1),
#  ('west virginia new york', 1),
#  ('western central pa', 1),
#  ('sicily italy', 1),
#  ('sailing caribbean', 1),
#  ('day6 promoter', 1),
#  ('lorton va', 1),
#  ('side', 1),
#  ('behind you', 1),
#  ('gainesville oklahoma', 1),
#  ('club tropicana', 1),
#  ('she her \x89û¢ yugihoes', 1),
#  ('aretì©', 1),
#  ('austintown oh', 1),
#  ('quit creaping', 1),
#  ('zadar croatia', 1),
#  ('mbabane swaziland', 1),
#  ('closet creepy smirk', 1),
#  ('nevada', 1),
#  ('main line', 1),
#  ('ny tri state area', 1),
#  ('1 6 1 5 1 2', 1),
#  ('asexual paradise', 1),
#  ('island quivering nrvs', 1),
#  ('kluang johor', 1),
#  ('greater nyc area', 1),
#  ('wesley lowery washpost com', 1),
#  ('paraguay', 1),
#  ('t lm defense squad', 1),
#  ('chester', 1),
#  ('get normani video', 1),
#  ('hood college 19', 1),
#  ('olympic penisula wa', 1),
#  ('htx \x89ïö kentucky', 1),
#  ('durham liverpool', 1),
#  ('malang jawa timur', 1),
#  ('ecuador', 1),
#  ('usa ashland', 1),
#  ('heart lost australia ìäire', 1),
#  ('compton', 1),
#  ('toronto london england', 1),
#  ('2\x89ä£5\x89ä£2\x89ä£ 7\x89ä£5\x89ä£7\x89ä£', 1),
#  ('hell venezuela', 1),
#  ('studio e', 1),
#  ('livorno', 1),
#  ('kylee madeline make', 1),
#  ('small town usa', 1),
#  ('syria', 1),
#  ('pawtucket ri u s army', 1),
#  ('cupertino ca', 1),
#  ('hackney', 1),
#  ('dressa ceci', 1),
#  ('mi \x89ïö\x95ü\x8f fl \x89ïö\x95ü\x8f la', 1),
#  ('greenland', 1),
#  ('london bergamo', 1),
#  ('washington dc metro area', 1),
#  ('lakewood nj', 1),
#  ('19 forever', 1),
#  ('wishaniggawoods', 1),
#  ...]

# %% [markdown]
# ## Question 3

# %%
import tweepy
from tweepy import OAuthHandler

consumer_key = 'aZgjP0NZeM4iiBaQXJcyOKLJB'
consumer_secret = 'VRLyop5JLP8Kh91CMnE0rpOKUhKEtrrVTCOozHVOd8QEFx69XX'
access_token = '326266960-9RZItG8Q4FUER0BOX4eO8mrvsvrrDWzaWiJqoens'
access_secret = 'v6UHn9puTUv5OgcDwGqf3UxfCZv6XSJZ1gB8UkXOFrnQo'

auth = OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_secret)

api = tweepy.API(auth)

# %%
from tweepy import Stream
from tweepy.streaming import StreamListener
import json
import os

# %%
JSON_FILE_NAME='usa_tweets.json'
MAX_NUMBER_OF_TWEETS = 10
tweets_gathered = 0
f = open(JSON_FILE_NAME, 'w')
f.write('[')
#writer = csv.writer(f)
class MyListener(StreamListener):
    
    def on_data(self, data):
        global tweets_gathered
        if MAX_NUMBER_OF_TWEETS > tweets_gathered:
            tweets_gathered += 1
            try:
                #print(api.get_user(json.loads(data)['user']['id'])['gender']) - sadly will not work..
                f.write(data.rstrip() + ',')
                return True
            except BaseException as e:
                print("Error on_data: %s" % str(e))
            return True
        else:
            f.seek
            return False
 
    def on_error(self, status):
        print(status)
        return True
 
twitter_stream = Stream(auth, MyListener())
# those coordinates are boxed that represents most of america - the country that we've found to have the most tweetings. 
twitter_stream.filter(locations=[-124.89,32.7,-93.07,48.99,
                                 -110.64,31.98,-84.43,47.01,
                                -99.04,26.29,-72.83,41.58,
                                -79.0,32.1,-70.6,43.69,
                                -75.3,41.06,-66.91,45.06])
f.close()
#just a fix to the json file
with open(JSON_FILE_NAME, 'rb+') as f:
    f.seek(-1, os.SEEK_END)
    f.write(b']')

# %%
new_twitts_df = pd.read_json(path_or_buf=JSON_FILE_NAME)
display(new_twitts_df)
# Can't get twitts gender - arghhhh
# Out:
#    contributors                                        coordinates  \
# 0           NaN                                               None
# 1           NaN                                               None
# 2           NaN                                               None
# 3           NaN                                               None
# 4           NaN                                               None
# 5           NaN  {'type': 'Point', 'coordinates': [-79.41933056...
# 6           NaN                                               None
# 7           NaN  {'type': 'Point', 'coordinates': [-122.39872, ...
# 8           NaN                                               None
# 9           NaN                                               None
#
#            created_at display_text_range  \
# 0 2018-01-20 23:05:25           [12, 39]
# 1 2018-01-20 23:05:25           [22, 29]
# 2 2018-01-20 23:05:25                NaN
# 3 2018-01-20 23:05:25           [15, 53]
# 4 2018-01-20 23:05:25                NaN
# 5 2018-01-20 23:05:25                NaN
# 6 2018-01-20 23:05:25           [12, 50]
# 7 2018-01-20 23:05:25                NaN
# 8 2018-01-20 23:05:25             [0, 3]
# 9 2018-01-20 23:05:25             [0, 0]
#
#                                             entities  \
# 0  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 1  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 2  {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 3  {'hashtags': [{'text': 'prfest', 'indices': [1...
# 4  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 5  {'hashtags': [{'text': 'wychwoodpark', 'indice...
# 6  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 7  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 8  {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 9  {'hashtags': [], 'urls': [], 'user_mentions': ...
#
#                                    extended_entities  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9  {'media': [{'id': 954852380792602624, 'id_str'...
#
#                                       extended_tweet  favorite_count  \
# 0                                                NaN               0
# 1                                                NaN               0
# 2  {'full_text': 'i wonder if mike pence will cal...               0
# 3                                                NaN               0
# 4                                                NaN               0
# 5                                                NaN               0
# 6                                                NaN               0
# 7                                                NaN               0
# 8                                                NaN               0
# 9                                                NaN               0
#
#    favorited filter_level                                                geo  \
# 0      False          low                                               None
# 1      False          low                                               None
# 2      False          low                                               None
# 3      False          low                                               None
# 4      False          low                                               None
# 5      False          low  {'type': 'Point', 'coordinates': [43.67806111,...
# 6      False          low                                               None
# 7      False          low  {'type': 'Point', 'coordinates': [37.781157, -...
# 8      False          low                                               None
# 9      False          low                                               None
#
#                    id              id_str in_reply_to_screen_name  \
# 0  954852391949668353  954852391949668352              dank_bagel
# 1  954852392008339456  954852392008339456              HopeFloeck
# 2  954852392557834241  954852392557834240                    None
# 3  954852392473890818  954852392473890816           CoachCloutier
# 4  954852392796872704  954852392796872704                    None
# 5  954852393002389505  954852393002389504                    None
# 6  954852393182744578  954852393182744576              adaojiakor
# 7  954852393262505984  954852393262505984                    None
# 8  954852393329528834  954852393329528832                    None
# 9  954852393174355969  954852393174355968                    None
#
#    in_reply_to_status_id  in_reply_to_status_id_str  in_reply_to_user_id  \
# 0           9.548483e+17               9.548483e+17         2.989582e+07
# 1           9.548135e+17               9.548135e+17         1.552124e+09
# 2                    NaN                        NaN                  NaN
# 3           9.547065e+17               9.547065e+17         8.789985e+08
# 4                    NaN                        NaN                  NaN
# 5                    NaN                        NaN                  NaN
# 6           9.548521e+17               9.548521e+17         1.713060e+08
# 7                    NaN                        NaN                  NaN
# 8                    NaN                        NaN                  NaN
# 9                    NaN                        NaN                  NaN
#
#    in_reply_to_user_id_str  is_quote_status lang  \
# 0             2.989582e+07            False   en
# 1             1.552124e+09            False   en
# 2                      NaN            False   en
# 3             8.789985e+08            False   en
# 4                      NaN            False   en
# 5                      NaN            False   pl
# 6             1.713060e+08            False   en
# 7                      NaN            False   in
# 8                      NaN             True  und
# 9                      NaN            False  und
#
#                                                place  possibly_sensitive  \
# 0  {'id': '8e9665cec9370f0f', 'url': 'https://api...                 NaN
# 1  {'id': 'f7bb6752fbd343e9', 'url': 'https://api...                 NaN
# 2  {'id': '00f751614d8ce37b', 'url': 'https://api...                 NaN
# 3  {'id': 'ed2f91f4683ea25f', 'url': 'https://api...                 NaN
# 4  {'id': '813a485b26b8dae2', 'url': 'https://api...                 NaN
# 5  {'id': '3797791ff9c0e4c6', 'url': 'https://api...                 0.0
# 6  {'id': '38d5974e82ed1a6c', 'url': 'https://api...                 NaN
# 7  {'id': '5a110d312052166f', 'url': 'https://api...                 NaN
# 8  {'id': '7543692056063d2f', 'url': 'https://api...                 0.0
# 9  {'id': '3df4f427b5a60fea', 'url': 'https://api...                 0.0
#
#    quote_count                                      quoted_status  \
# 0            0                                                NaN
# 1            0                                                NaN
# 2            0                                                NaN
# 3            0                                                NaN
# 4            0                                                NaN
# 5            0                                                NaN
# 6            0                                                NaN
# 7            0                                                NaN
# 8            0  {'created_at': 'Sat Jan 20 23:02:12 +0000 2018...
# 9            0                                                NaN
#
#    quoted_status_id  quoted_status_id_str  reply_count  retweet_count  \
# 0               NaN                   NaN            0              0
# 1               NaN                   NaN            0              0
# 2               NaN                   NaN            0              0
# 3               NaN                   NaN            0              0
# 4               NaN                   NaN            0              0
# 5               NaN                   NaN            0              0
# 6               NaN                   NaN            0              0
# 7               NaN                   NaN            0              0
# 8      9.548516e+17          9.548516e+17            0              0
# 9               NaN                   NaN            0              0
#
#    retweeted                                             source  \
# 0      False  <a href="http://twitter.com/download/android" ...
# 1      False  <a href="http://twitter.com/download/iphone" r...
# 2      False  <a href="http://twitter.com" rel="nofollow">Tw...
# 3      False  <a href="http://twitter.com/download/iphone" r...
# 4      False  <a href="http://twitter.com/download/iphone" r...
# 5      False  <a href="http://instagram.com" rel="nofollow">...
# 6      False  <a href="http://twitter.com/download/iphone" r...
# 7      False  <a href="http://twitter.com" rel="nofollow">Ge...
# 8      False  <a href="http://twitter.com/download/iphone" r...
# 9      False  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text            timestamp_ms  \
# 0            @dank_bagel but is it decent quality??? 2018-01-20 23:05:25.197
# 1                      @HopeFloeck @LassMike Oh no!! 2018-01-20 23:05:25.211
# 2  i wonder if mike pence will call my student lo... 2018-01-20 23:05:25.342
# 3  @CoachCloutier #prfest w Mohon girls too! #moh... 2018-01-20 23:05:25.322
# 4                    Heaven so close I could kiss it 2018-01-20 23:05:25.399
# 5  #wychwoodpark #wychwood #winter #wintermission... 2018-01-20 23:05:25.448
# 6  @adaojiakor I stopped eating after the second ... 2018-01-20 23:05:25.491
# 7  TEST_LAT/LON: 078f1355-dc8f-4da1-a1af-4cda15c2... 2018-01-20 23:05:25.510
# 8                        Mbn https://t.co/xwRyzlkKN6 2018-01-20 23:05:25.526
# 9                            https://t.co/qcHpvG1Jnf 2018-01-20 23:05:25.489
#
#    truncated                                               user
# 0      False  {'id': 245152688, 'id_str': '245152688', 'name...
# 1      False  {'id': 710864108992602112, 'id_str': '71086410...
# 2       True  {'id': 19188730, 'id_str': '19188730', 'name':...
# 3      False  {'id': 3525012017, 'id_str': '3525012017', 'na...
# 4      False  {'id': 922318724, 'id_str': '922318724', 'name...
# 5      False  {'id': 775017472416186368, 'id_str': '77501747...
# 6      False  {'id': 226996684, 'id_str': '226996684', 'name...
# 7      False  {'id': 758415480881164288, 'id_str': '75841548...
# 8      False  {'id': 1661137176, 'id_str': '1661137176', 'na...
# 9      False  {'id': 515901418, 'id_str': '515901418', 'name...
