# %% [markdown]
# <h1> Word Embedding - Pre Trained Model</h1>

# %% [markdown]
# We are going to use google’s <a href="https://drive.google.com/uc?id=0B7XkCwpI5KDYNlNUTTlSS21pQmM&export=download">pre-trained model</a> . It contains word vectors for a vocabulary of 3 million words trained on around 100 billion words from the google news dataset. The downlaod link for the model is this. Beware it is a 1.5 GB download.

# %%
from gensim.models import Word2Vec

# %%
#loading the downloaded model
from gensim.models import KeyedVectors

filename = 'c:\\asi\\webmining\\GoogleNews-vectors-negative300.bin'
model = KeyedVectors.load_word2vec_format(filename, binary=True)

# %%
# getting word vectors of a word
dog = model['dog']
print(dog)
print(dog.shape)
# Out:
# [  5.12695312e-02  -2.23388672e-02  -1.72851562e-01   1.61132812e-01
#   -8.44726562e-02   5.73730469e-02   5.85937500e-02  -8.25195312e-02
#   -1.53808594e-02  -6.34765625e-02   1.79687500e-01  -4.23828125e-01
#   -2.25830078e-02  -1.66015625e-01  -2.51464844e-02   1.07421875e-01
#   -1.99218750e-01   1.59179688e-01  -1.87500000e-01  -1.20117188e-01
#    1.55273438e-01  -9.91210938e-02   1.42578125e-01  -1.64062500e-01
#   -8.93554688e-02   2.00195312e-01  -1.49414062e-01   3.20312500e-01
#    3.28125000e-01   2.44140625e-02  -9.71679688e-02  -8.20312500e-02
#   -3.63769531e-02  -8.59375000e-02  -9.86328125e-02   7.78198242e-03
#   -1.34277344e-02   5.27343750e-02   1.48437500e-01   3.33984375e-01
#    1.66015625e-02  -2.12890625e-01  -1.50756836e-02   5.24902344e-02
#   -1.07421875e-01  -8.88671875e-02   2.49023438e-01  -7.03125000e-02
#   -1.59912109e-02   7.56835938e-02  -7.03125000e-02   1.19140625e-01
#    2.29492188e-01   1.41601562e-02   1.15234375e-01   7.50732422e-03
# ...

# %%
#performing king queen magic
print(model.most_similar(positive=['woman', 'king'], negative=['man']))
# Out:
# [(u'queen', 0.7118192911148071), (u'monarch', 0.6189674139022827), (u'princess', 0.5902431607246399), (u'crown_prince', 0.5499460697174072), (u'prince', 0.5377321243286133), (u'kings', 0.5236844420433044), (u'Queen_Consort', 0.5235945582389832), (u'queens', 0.5181134343147278), (u'sultan', 0.5098593235015869), (u'monarchy', 0.5087411999702454)]

# %%
#picking odd one out
print(model.doesnt_match("breakfast cereal dinner lunch".split()))
# Out:
# cereal

# %%
#printing similarity index
print(model.similarity('woman', 'man'))
# Out:
# 0.7664012231
